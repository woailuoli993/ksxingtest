# %% [markdown]
# # rollaxis 实例

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.misc

# %%
b = scipy.misc.imread('magic.png')

# %%
b.dtype
# Out:
# dtype('uint8')

# %%
toimage(b)
# Out:
# <PIL.Image.Image image mode=RGBA size=572x810 at 0x10B6DC0F0>

# %%
b.shape
# Out:
# (810, 572, 4)

# %%
c = np.rollaxis(b, 1)

# %%
c.shape
# Out:
# (572, 810, 4)

# %%
toimage(c)
# Out:
# <PIL.Image.Image image mode=RGBA size=810x572 at 0x10C2457B8>

# %%
d = np.swapaxes(b, 0, 1)

# %%
d.shape
# Out:
# (572, 810, 4)

# %%
toimage(d)
# Out:
# <PIL.Image.Image image mode=RGBA size=810x572 at 0x10C26FCC0>
